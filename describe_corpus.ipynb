# %% [markdown]
# # Tools for exploring the structure of longform articles

# %% [markdown]
# Import the necessary packages.

# %%
import xml.etree.ElementTree as et
import numpy as np
import glob
from itertools import cycle
from collections import Counter as c
import os
import re

# %% [markdown]
# Load the annotated data from the XML file.

# %%
annotations_dir = 'Annotations'

# %%
xmlfiles = os.listdir(annotations_dir)

screens = [] # Empty list for screens

for xml_file in xmlfiles: 
    if re.search( r'xml$' , xml_file ):
        print(xml_file)
        path = os.path.join(annotations_dir,xml_file)
        annotation = et.parse(path) # Parse the XML annotation in specific file
        xmlroot = annotation.getroot() # Get the root element
        print(xmlroot.attrib['title'], '/', xmlroot.attrib['publisher'], '/', xmlroot.attrib['year'], '\n') # Print longform data
        for entry in xmlroot: # Iterate through the XML file
            screen = xmlroot.attrib['article_identifier'] + '-' + entry.attrib['identifier'], entry.attrib['mode'], entry.attrib['type'], entry.attrib['transition_in'], entry.attrib['transition_out']
            print( entry.attrib['identifier'], entry.attrib['mode'], entry.attrib['type'], entry.attrib['transition_in'], entry.attrib['transition_out'] )
            screens.append(screen)
        print('\n') # Extra line break
# Out:
# miami-building-collapse.xml
# Miami Building Collapse / New York Times / 2021
#
# 0001 dynamic-image-flow dynamic none scroll
# 0002 dynamic-image-flow dynamic none scroll
# 0003 dynamic-image-flow dynamic none scroll
# 0004 dynamic-image-flow dynamic none scroll
#
#
# ukraine-maps.xml
# Ukraine Maps / New York Times / 2022
#
# 0001 text-flow static none scroll
# 0002 text-flow static none scroll
# 0003 text-flow static none scroll
# 0004 text-flow static none scroll
# 0005 text-flow static none scroll
# 0006 text-flow static none scroll
# 0007 text-flow static none scroll
# 0008 text-flow static none scroll
# 0009 text-flow static none scroll
#
#
# covid-risk-map.xml
# Covid Risk Map / New York Times / 2019
#
# 0001 text-flow static none scroll
# 0002 text-flow static none scroll
# 0003 text-flow static none scroll
# 0004 text-flow static none scroll
# 0005 text-flow static none scroll
# 0006 text-flow static none scroll
# 0007 text-flow static none scroll
# 0008 text-flow static none scroll
# 0009 text-flow static none scroll
#
#
# covid-vaccinations-tracker.xml
# Covid Vaccinations Tracker / New York Times / 2019
#
# 0001 text-flow static none scroll
# 0002 text-flow static none scroll
# 0003 text-flow static none scroll
# 0004 text-flow static none scroll
# 0005 text-flow static none scroll
# 0006 text-flow static none scroll
# 0007 text-flow static none scroll
# 0008 text-flow static none scroll
#
#
# infrastructure-breakdown.xml
# Infrastructure Breakdown / New York Times / 2021
#
# 0001 text-flow static none scroll
# 0002 text-flow static none scroll
# 0003 text-flow static none scroll
# 0004 text-flow static none scroll
# 0005 text-flow static none scroll
# 0006 text-flow static none scroll
# 0007 text-flow static none scroll
# 0008 text-flow static none scroll
# 0009 text-flow static none scroll
# 0010 text-flow static none scroll
# 0011 text-flow static none scroll
# 0012 text-flow static none scroll
# 0013 text-flow static none scroll
# 0014 text-flow static none scroll
# 0015 text-flow static none scroll
# 0016 text-flow static none scroll
#
#
# san-francisco-fog.xml
# San Francisco Fog / New York Times / 2022
#
# 0001 text-flow static none scroll
# 0002 text-flow static none scroll
# 0003 text-flow static none scroll
# 0004 text-flow static none scroll
# 0005 text-flow static none scroll
# 0006 text-flow static none scroll
# 0007 text-flow static none scroll
# 0008 text-flow static none scroll
# 0009 text-flow static none scroll
# 0010 audio static none scroll
# 0011 text-flow static none scroll
# 0012 static-image static none scroll
# 0013 static-image static none scroll
# 0014 text-flow static none scroll
# 0015 text-flow static none scroll
# 0016 text-flow static none scroll
# 0017 text-flow static none scroll
# 0018 text-flow static none scroll
# 0019 text-flow static none scroll
# 0020 text-flow static none scroll
# 0021 text-flow static none scroll
# 0022 text-flow static none scroll
# 0023 text-flow static none scroll
# 0024 text-flow static none scroll
# 0025 static-image static none scroll
# 0026 static-image static none scroll
# 0027 text-flow static none scroll
# 0028 text-flow static none scroll
# 0029 text-flow static none scroll
# 0030 text-flow static none scroll
# 0031 text-flow static none scroll
# 0032 text-flow static none scroll
# 0033 static-image static none scroll
# 0034 text-flow static none scroll
# 0035 text-flow static none scroll
# 0036 text-flow static none scroll
# 0037 text-flow static none scroll
# 0038 text-flow static none scroll
# 0039 text-flow static none scroll
# 0040 text-flow static none scroll
# 0041 text-flow static none scroll
# 0042 text-flow static none scroll
# 0043 text-flow static none scroll
# 0044 text-flow static none scroll
# 0045 text-flow static none scroll
# 0046 text-flow static none scroll
# 0047 text-flow static none scroll
# 0048 text-flow static none scroll
# 0049 text-flow static none scroll
# 0050 text-flow static none scroll
# 0051 text-flow static none scroll
# 0052 text-flow static none scroll
# 0053 text-flow static none scroll
# 0054 text-flow static none scroll
# 0055 text-flow static none scroll
# 0056 text-flow static none scroll
# 0057 static-image static none scroll
# 0058 static-image static none scroll
# 0059 text-flow static none scroll
# 0060 text-flow static none scroll
# 0061 text-flow static none scroll
# 0062 text-flow static none scroll
# 0063 text-flow static none scroll
# 0064 text-flow static none scroll
# 0065 text-flow static none scroll
# 0066 text-flow static none scroll
# 0067 text-flow static none scroll
# 0068 static-image static none scroll
# 0069 text-flow static none scroll
# 0070 text-flow static none scroll
# 0071 text-flow static none scroll
# 0072 text-flow static none scroll
# 0073 text-flow static none scroll
# 0074 text-flow static none scroll
# 0075 text-flow static none scroll
# 0076 text-flow static none scroll
# 0077 text-flow static none scroll
# 0078 text-flow static none scroll
# 0079 text-flow static none scroll
# 0080 text-flow static none scroll
# 0081 text-flow static none scroll
# 0082 text-flow static none scroll
# 0083 text-flow static none scroll
# 0084 text-flow static none scroll
# 0085 text-flow static none scroll
# 0086 text-flow static none scroll
# 0087 text-flow static none scroll
# 0088 text-flow static none scroll
# 0089 text-flow static none scroll
# 0090 text-flow static none scroll
# 0091 text-flow static none scroll
# 0092 text-flow static none scroll
# 0093 text-flow static none scroll
# 0094 text-flow static none scroll
# 0095 text-flow static none scroll
# 0096 static-image static none scroll
# 0097 static-image static none scroll
# 0098 text-flow static none scroll
# 0099 text-flow static none scroll
# 0100 text-flow static none scroll
# 0101 text-flow static none scroll
# 0102 static-image static none scroll
# 0103 static-image static none scroll
# 0104 text-flow static none scroll
# 0105 text-flow static none scroll
# 0106 text-flow static none scroll
# 0107 text-flow static none scroll
# 0108 text-flow static none scroll
# 0109 static-image static none scroll
# 0110 text-flow static none scroll
# 0111 text-flow static none scroll
# 0112 text-flow static none scroll
# 0113 text-flow static none scroll
# 0114 text-flow static none scroll
# 0115 text-flow static none scroll
# 0116 text-flow static none scroll
# 0117 text-flow static none scroll
# 0118 text-flow static none scroll
# 0119 text-flow static none scroll
# 0120 static-image static none scroll
# 0121 static-image static none scroll
# 0122 text-flow static none scroll
# 0123 text-flow static none scroll
# 0124 text-flow static none scroll
# 0125 text-flow static none scroll
# 0126 text-flow static none scroll
# 0127 text-flow static none scroll
# 0128 text-flow static none scroll
# 0129 static-image static none scroll
# 0130 static-image static none scroll
# 0131 text-flow static none scroll
# 0132 text-flow static none scroll
# 0133 text-flow static none scroll
# 0134 text-flow static none scroll
# 0135 text-flow static none scroll
# 0136 static-image static none scroll
# 0137 text-flow static none scroll
# 0138 text-flow static none scroll
# 0139 text-flow static none scroll
# 0140 text-flow static none scroll
# 0141 text-flow static none scroll
# 0142 text-flow static none scroll
# 0143 text-flow static none scroll
# 0144 text-flow static none scroll
# 0145 text-flow static none scroll
# 0146 static-image static none scroll
# 0147 static-image static none scroll
# 0148 text-flow static none scroll
# 0149 text-flow static none scroll
# 0150 text-flow static none scroll
# 0151 text-flow static none scroll
# 0152 text-flow static none scroll
# 0153 text-flow static none scroll
# 0154 text-flow static none scroll
# 0155 text-flow static none scroll
# 0156 text-flow static none scroll
# 0157 text-flow static none scroll
# 0158 text-flow static none scroll
# 0159 text-flow static none scroll
# 0160 text-flow static none scroll
# 0161 text-flow static none scroll
# 0162 static-image static none scroll
# 0163 text-flow static none scroll
# 0164 text-flow static none scroll
# 0165 text-flow static none scroll
# 0166 text-flow static none scroll
# 0167 text-flow static none scroll
# 0168 text-flow static none scroll
# 0169 text-flow static none scroll
# 0170 text-flow static none scroll
# 0171 static-image static none scroll
# 0172 static-image static none scroll
# 0173 text-flow static none scroll
# 0174 text-flow static none scroll
# 0175 text-flow static none scroll
# 0176 text-flow static none scroll
# 0177 text-flow static none scroll
# 0178 text-flow static none scroll
# 0179 text-flow static none scroll
# 0180 text-flow static none scroll
# 0181 static-image static none scroll
# 0182 static-image static none scroll
# 0183 text-flow static none scroll
# 0184 text-flow static none scroll
# 0185 text-flow static none scroll
# 0186 text-flow static none scroll
# 0187 text-flow static none scroll
# 0188 text-flow static none scroll
# 0189 text-flow static none scroll
# 0190 text-flow static none scroll
# 0191 dynamic-image-flow dynamic none scroll
# 0192 dynamic-image-flow dynamic none scroll
# 0193 text-flow static none scroll
# 0194 text-flow static none scroll
# 0195 text-flow static none scroll
# 0196 text-flow static none scroll
# 0197 text-flow static none scroll
# 0198 text-flow static none scroll
# 0199 text-flow static none scroll
# 0200 text-flow static none scroll
# 0201 text-flow static none scroll
# 0202 text-flow static none scroll
#
#
# asian-american-photos-love.xml
# Asian American Photos Love / New York Times / 2021
#
# 0001 static-image static none scroll
# 0002 static-image static none scroll
# 0003 static-image static none scroll
# 0004 static-image static none scroll
# 0005 static-image static none scroll
# 0006 static-image static none scroll
# 0007 text-flow static none scroll
# 0008 text-flow static none scroll
# 0009 text-flow static none scroll
# 0010 text-flow static none scroll
# 0011 text-flow static none scroll
# 0012 text-flow static none scroll
# 0013 text-flow static none scroll
# 0014 static-image static none scroll
# 0015 static-image static none scroll
# 0016 static-image static none scroll
# 0017 static-image static none scroll
# 0018 text-flow static none scroll
# 0019 static-image static none scroll
# 0020 static-image static none scroll
# 0021 static-image static none scroll
# 0022 static-image static none scroll
# 0023 text-flow static none scroll
# 0024 static-image static none scroll
# 0025 text-flow static none scroll
# 0026 static-image static none scroll
# 0027 static-image static none scroll
# 0028 static-image static none scroll
# 0029 static-image static none scroll
# 0030 static-image static none scroll
# 0031 static-image static none scroll
# 0032 text-flow static none scroll
# 0033 static-image static none scroll
# 0034 static-image static none scroll
# 0035 static-image static none scroll
# 0036 text-flow static none scroll
# 0037 static-image static none scroll
# 0038 text-flow static none scroll
# 0039 static-image static none scroll
# 0040 static-image static none scroll
# 0041 static-image static none scroll
# 0042 static-image static none scroll
# 0043 static-image static none scroll
# 0044 static-image static none scroll
# 0045 static-image static none scroll
# 0046 static-image static none scroll
# 0047 text-flow static none scroll
# 0048 static-image static none scroll
# 0049 static-image static none scroll
# 0050 static-image static none scroll
# 0051 text-flow static none scroll
# 0052 text-flow static none scroll
# 0053 text-flow static none scroll
# 0054 text-flow static none scroll
# 0055 text-flow static none scroll
# 0056 text-flow static none scroll
# 0057 static-image static none scroll
# 0058 text-flow static none scroll
# 0059 static-image static none scroll
# 0060 static-image static none scroll
# 0061 static-image static none scroll
# 0062 static-image static none scroll
# 0063 static-image static none scroll
# 0064 text-flow static none scroll
# 0065 static-image static none scroll
# 0066 static-image static none scroll
# 0067 static-image static none scroll
# 0068 static-image static none scroll
# 0069 text-flow static none scroll
# 0070 static-image static none scroll
# 0071 static-image static none scroll
# 0072 static-image static none scroll
# 0073 text-flow static none scroll
# 0074 static-image static none scroll
# 0075 static-image static none scroll
# 0076 static-image static none scroll
# 0077 static-image static none scroll
# 0078 text-flow static none scroll
# 0079 static-image static none scroll
# 0080 static-image static none scroll
# 0081 static-image static none scroll
# 0082 text-flow static none scroll
# 0083 static-image static none scroll
# 0084 static-image static none scroll
# 0085 static-image static none scroll
# 0086 static-image static none scroll
# 0087 static-image static none scroll
# 0088 static-image static none scroll
# 0089 text-flow static none scroll
# 0090 static-image static none scroll
# 0091 static-image static none scroll
# 0092 static-image static none scroll
# 0093 static-image static none scroll
# 0094 text-flow static none scroll
# 0095 static-image static none scroll
# 0096 static-image static none scroll
# 0097 static-image static none scroll
# 0098 text-flow static none scroll
# 0099 static-image static none scroll
# 0100 static-image static none scroll
# 0101 static-image static none scroll
# 0102 static-image static none scroll
# 0103 text-flow static none scroll
# 0104 static-image static none scroll
# 0105 static-image static none scroll
# 0106 static-image static none scroll
# 0107 static-image static none scroll
# 0108 static-image static none scroll
# 0109 text-flow static none scroll
# 0110 text-flow static none scroll
# 0111 text-flow static none scroll
# 0112 text-flow static none scroll
# 0113 text-flow static none scroll
# 0114 text-flow static none scroll
# 0115 text-flow static none scroll
# 0116 text-flow static none scroll
# 0117 static-image static none scroll
# 0118 static-image static none scroll
# 0119 static-image static none scroll
# 0120 text-flow static none scroll
# 0121 static-image static none scroll
# 0122 static-image static none scroll
# 0123 static-image static none scroll
# 0124 static-image static none scroll
# 0125 static-image static none scroll
# 0126 static-image static none scroll
# 0127 text-flow static none scroll
# 0128 static-image static none scroll
# 0129 text-flow static none scroll
# 0130 static-image static none scroll
# 0131 static-image static none scroll
# 0132 static-image static none scroll
# 0133 static-image static none scroll
# 0134 static-image static none scroll
# 0135 text-flow static none scroll
# 0136 static-image static none scroll
# 0137 static-image static none scroll
# 0138 text-flow static none scroll
# 0139 static-image static none scroll
# 0140 static-image static none scroll
# 0141 static-image static none scroll
# 0142 static-image static none scroll
# 0143 text-flow static none scroll
# 0144 static-image static none scroll
# 0145 static-image static none scroll
# 0146 static-image static none scroll
# 0147 static-image static none scroll
# 0148 static-image static none scroll
# 0149 text-flow static none scroll
# 0150 static-image static none scroll
# 0151 text-flow static none scroll
# 0152 static-image static none scroll
# 0153 static-image static none scroll
# 0154 text-flow static none scroll
# 0155 text-flow static none scroll
# 0156 text-flow static none scroll
#
#
# olympic-races.xml
# Olympic Races / New York Times / 2000
#
# 0001 static-image static none scroll
# 0002 text-flow static none scroll
# 0003 text-flow static none scroll
# 0004 text-flow static none scroll
# 0005 text-flow static none scroll
# 0006 text-flow static none scroll
# 0007 text-flow static none scroll
# 0008 text-flow static none scroll
# 0009 text-flow static none scroll
# 0010 text-flow static none scroll
# 0011 text-flow static none scroll
#
#
# bike-ride-italy-croatia.xml
# Bike Ride Italy Croatia / New York Times / 2022
#
# 0001 text-flow static none scroll
# 0002 text-flow static none scroll
# 0003 text-flow static none scroll
# 0004 text-flow static none scroll
# 0005 static-image static none scroll
# 0006 text-flow static none scroll
# 0007 text-flow static none scroll
# 0008 text-flow static none scroll
# 0009 static-image static none scroll
# 0010 text-flow static none scroll
# 0011 text-flow static none scroll
# 0012 text-flow static none scroll
# 0013 dynamic-image-flow dynamic none scroll
# 0014 dynamic-image-flow dynamic none scroll
# 0015 text-flow static none scroll
# 0016 text-flow static none scroll
# 0017 static-image static none scroll
# 0018 text-flow static none scroll
# 0019 static-image static none scroll
# 0020 text-flow static none scroll
# 0021 text-flow static none scroll
# 0022 static-image static none scroll
# 0023 text-flow static none scroll
# 0024 text-flow static none scroll
# 0025 static-image static none scroll
# 0026 text-flow static none scroll
# 0027 text-flow static none scroll
# 0028 static-image static none scroll
# 0029 text-flow static none scroll
# 0030 text-flow static none scroll
# 0031 static-image static none scroll
# 0032 text-flow static none scroll
# 0033 text-flow static none scroll
# 0034 text-flow static none scroll
# 0035 dynamic-image-flow dynamic none scroll
# 0036 dynamic-image-flow dynamic none scroll
# 0037 text-flow static none scroll
# 0038 text-flow static none scroll
# 0039 static-image static none scroll
# 0040 text-flow static none scroll
# 0041 text-flow static none scroll
# 0042 dynamic-image-flow dynamic none scroll
# 0043 dynamic-image-flow dynamic none scroll
# 0044 text-flow static none scroll
# 0045 static-image static none scroll
# 0046 text-flow static none scroll
# 0047 static-image static none scroll
# 0048 text-flow static none scroll
# 0049 text-flow static none scroll
# 0050 static-image static none scroll
# 0051 text-flow static none scroll
# 0052 static-image static none scroll
# 0053 text-flow static none scroll
# 0054 text-flow static none scroll
# 0055 text-flow static none scroll
# 0056 text-flow static none scroll
# 0057 text-flow static none scroll
# 0058 text-flow static none scroll
#
#
# environmental-inequity-trees-critical-infrastructure.xml
# Environmental Inequity Trees Critical Infrastructure / New York Times / 2021
#
# 0001 text-flow static none scroll
# 0002 text-flow static none scroll
# 0003 text-flow static none scroll
# 0004 text-flow static none scroll
# 0005 text-flow static none scroll
# 0006 text-flow static none scroll
# 0007 text-flow static none scroll
# 0008 text-flow static none scroll
# 0009 text-flow static none scroll
# 0010 text-flow static none scroll
# 0011 text-flow static none scroll
# 0012 text-flow static none scroll
# 0013 text-flow static none scroll
# 0014 text-flow static none scroll
# 0015 text-flow static none scroll
# 0016 text-flow static none scroll
# 0017 text-flow static none scroll
# 0018 text-flow static none scroll
# 0019 text-flow static none scroll
# 0020 text-flow static none scroll
#
#
# major-league-baseball-spin-rate-shift.xml
# Major League Baseball Spin Rate Shift / New York Times / 2021
#
# 0001 text-flow static none scroll
# 0002 text-flow static none scroll
# 0003 text-flow static none scroll
# 0004 text-flow static none scroll
# 0005 text-flow static none scroll
# 0006 text-flow static none scroll
# 0007 text-flow static none scroll
# 0008 text-flow static none scroll
# 0009 text-flow static none scroll
# 0010 text-flow static none scroll
# 0011 text-flow static none scroll
# 0012 text-flow static none scroll
# 0013 text-flow static none scroll
# 0014 text-flow static none scroll
# 0015 text-flow static none scroll
# 0016 text-flow static none scroll
# 0017 text-flow static none scroll
# 0018 text-flow static none scroll
# 0019 text-flow static none scroll
# 0020 text-flow static none scroll
# 0021 text-flow static none scroll
# 0022 text-flow static none scroll
# 0023 text-flow static none scroll
# 0024 text-flow static none scroll
# 0025 text-flow static none scroll
# 0026 text-flow static none scroll
# 0027 text-flow static none scroll
# 0028 text-flow static none scroll
# 0029 text-flow static none scroll
# 0030 text-flow static none scroll
# 0031 text-flow static none scroll
# 0032 text-flow static none scroll
# 0033 text-flow static none scroll
#
#
# ranked-choice-voting-nyc.xml
# Ranked Choice Voting Nyc / New York Times / 2021
#
# 0001 static-image static none scroll
# 0002 static-image static none scroll
# 0003 text-flow static none scroll
# 0004 text-flow static none scroll
# 0005 text-flow static none scroll
# 0006 text-flow static none scroll
# 0007 text-flow static none scroll
# 0008 text-flow static none scroll
# 0009 text-flow static none scroll
# 0010 text-flow static none scroll
# 0011 text-flow static none scroll
# 0012 text-flow static none scroll
# 0013 text-flow static none scroll
# 0014 text-flow static none scroll
# 0015 text-flow static none scroll
# 0016 text-flow static none scroll
# 0017 text-flow static none scroll
# 0018 text-flow static none scroll
# 0019 text-flow static none scroll
# 0020 text-flow static none scroll
# 0021 text-flow static none scroll
# 0022 text-flow static none scroll
# 0023 text-flow static none scroll
# 0024 text-flow static none scroll
# 0025 text-flow static none scroll
# 0026 text-flow static none scroll
# 0027 text-flow static none scroll
# 0028 text-flow static none scroll
# 0029 text-flow static none scroll
# 0030 text-flow static none scroll
# 0031 text-flow static none scroll
# 0032 text-flow static none scroll
# 0033 text-flow static none scroll
# 0034 text-flow static none scroll
# 0035 text-flow static none scroll
# 0036 static-image static none scroll
# 0037 text-flow static none scroll
# 0038 text-flow static none scroll
# 0039 text-flow static none scroll
# 0040 text-flow static none scroll
# 0041 text-flow static none scroll
# 0042 text-flow static none scroll
# 0043 text-flow static none scroll
# 0044 text-flow static none scroll
# 0045 text-flow static none scroll
# 0046 text-flow static none scroll
# 0047 text-flow static none scroll
# 0048 text-flow static none scroll
# 0049 text-flow static none scroll
# 0050 text-flow static none scroll
# 0051 text-flow static none scroll
# 0052 text-flow static none scroll
# 0053 text-flow static none scroll
# 0054 text-flow static none scroll
# 0055 text-flow static none scroll
# 0056 text-flow static none scroll
# 0057 text-flow static none scroll
#
#
# covid-prison-outbreak.xml
# Covid Prison Outbreak / New York Times / 2019
#
# 0001 text-flow static none scroll
# 0002 text-flow static none scroll
# 0003 text-flow static none scroll
# 0004 text-flow static none scroll
# 0005 text-flow static none scroll
# 0006 text-flow static none scroll
# 0007 text-flow static none scroll
# 0008 text-flow static none scroll
# 0009 text-flow static none scroll
# 0010 text-flow static none scroll
# 0011 text-flow static none scroll
# 0012 text-flow static none scroll
# 0013 text-flow static none scroll
# 0014 text-flow static none scroll
# 0015 text-flow static none scroll
# 0016 text-flow static none scroll
# 0017 text-flow static none scroll
# 0018 text-flow static none scroll
# 0019 text-flow static none scroll
# 0020 text-flow static none scroll
# 0021 text-flow static none scroll
# 0022 text-flow static none scroll
# 0023 text-flow static none scroll
# 0024 text-flow static none scroll
# 0025 text-flow static none scroll
# 0026 text-flow static none scroll
# 0027 text-flow static none scroll
# 0028 text-flow static none scroll
# 0029 text-flow static none scroll
# 0030 text-flow static none scroll
# 0031 text-flow static none scroll
# 0032 text-flow static none scroll
# 0033 text-flow static none scroll
# 0034 text-flow static none scroll
# 0035 text-flow static none scroll
# 0036 text-flow static none scroll
# 0037 text-flow static none scroll
# 0038 text-flow static none scroll
# 0039 text-flow static none scroll
# 0040 text-flow static none scroll
# 0041 text-flow static none scroll
# 0042 text-flow static none scroll
# 0043 text-flow static none scroll
# 0044 text-flow static none scroll
# 0045 text-flow static none scroll
# 0046 text-flow static none scroll
# 0047 text-flow static none scroll
# 0048 text-flow static none scroll
# 0049 text-flow static none scroll
# 0050 text-flow static none scroll
# 0051 text-flow static none scroll
# 0052 text-flow static none scroll
# 0053 text-flow static none scroll
# 0054 text-flow static none scroll
# 0055 text-flow static none scroll
# 0056 text-flow static none scroll
# 0057 text-flow static none scroll
# 0058 text-flow static none scroll
# 0059 text-flow static none scroll
# 0060 text-flow static none scroll
# 0061 text-flow static none scroll
# 0062 text-flow static none scroll
# 0063 text-flow static none scroll
# 0064 text-flow static none scroll
# 0065 text-flow static none scroll
# 0066 text-flow static none scroll
# 0067 text-flow static none scroll
# 0068 text-flow static none scroll
# 0069 text-flow static none scroll
# 0070 text-flow static none scroll
# 0071 text-flow static none scroll
# 0072 text-flow static none scroll
# 0073 text-flow static none scroll
# 0074 text-flow static none scroll
# 0075 text-flow static none scroll
# 0076 text-flow static none scroll
# 0077 text-flow static none scroll
# 0078 text-flow static none scroll
# 0079 text-flow static none scroll
# 0080 text-flow static none scroll
# 0081 text-flow static none scroll
# 0082 text-flow static none scroll
# 0083 text-flow static none scroll
# 0084 text-flow static none scroll
# 0085 text-flow static none scroll
# 0086 text-flow static none scroll
# 0087 text-flow static none scroll
#
#
# dominican-soundsystems.xml
# Dominican Soundsystems / New York Times / 2021
#
# 0001 dynamic-image-flow dynamic none scroll
# 0002 dynamic-image-flow dynamic none scroll
# 0003 dynamic-image-flow dynamic none scroll
# 0004 text-flow static none scroll
# 0005 text-flow static none scroll
# 0006 audio static none scroll
# 0007 text-flow static none scroll
# 0008 static-image static none scroll
# 0009 static-image static none scroll
# 0010 static-image static none scroll
# 0011 static-image static none scroll
# 0012 static-image static none scroll
# 0013 text-flow static none scroll
# 0014 text-flow static none scroll
# 0015 text-flow static none scroll
# 0016 text-flow static none scroll
# 0017 text-flow static none scroll
# 0018 static-image static none scroll
# 0019 dynamic-image-flow dynamic none scroll
# 0020 static-image static none scroll
# 0021 static-image static none scroll
# 0022 text-flow static none scroll
# 0023 text-flow static none scroll
# 0024 text-flow static none scroll
# 0025 text-flow static none scroll
# 0026 text-flow static none scroll
# 0027 text-flow static none scroll
# 0028 text-flow static none scroll
# 0029 static-image static none scroll
# 0030 static-image static none scroll
# 0031 dynamic-image-flow dynamic none scroll
# 0032 text-flow static none scroll
# 0033 text-flow static none scroll
# 0034 text-flow static none scroll
# 0035 static-image static none scroll
# 0036 static-image static none scroll
# 0037 static-image static none scroll
# 0038 static-image static none scroll
# 0039 static-image static none scroll
# 0040 static-image static none scroll
# 0041 text-flow static none scroll
# 0042 text-flow static none scroll
# 0043 text-flow static none scroll
# 0044 text-flow static none scroll
# 0045 text-flow static none scroll
# 0046 text-flow static none scroll
# 0047 static-image static none scroll
# 0048 dynamic-image-flow dynamic none scroll
# 0049 static-image static none scroll
# 0050 static-image static none scroll
# 0051 text-flow static none scroll
# 0052 text-flow static none scroll
# 0053 text-flow static none scroll
# 0054 text-flow static none scroll
#
#
# partisan-segregation-maps.xml
# Partisan Segregation Maps / New York Times / 2021
#
# 0001 text-flow static none scroll
# 0002 text-flow static none scroll
# 0003 text-flow static none scroll
# 0004 text-flow static none scroll
# 0005 text-flow static none scroll
# 0006 text-flow static none scroll
# 0007 text-flow static none scroll
# 0008 text-flow static none scroll
# 0009 text-flow static none scroll
# 0010 text-flow static none scroll
# 0011 text-flow static none scroll
# 0012 text-flow static none scroll
# 0013 text-flow static none scroll
# 0014 text-flow static none scroll
# 0015 text-flow static none scroll
# 0016 text-flow static none scroll
# 0017 text-flow static none scroll
# 0018 text-flow static none scroll
# 0019 text-flow static none scroll
# 0020 text-flow static none scroll
# 0021 text-flow static none scroll
# 0022 text-flow static none scroll
# 0023 text-flow static none scroll
# 0024 text-flow static none scroll
# 0025 text-flow static none scroll
# 0026 text-flow static none scroll
# 0027 text-flow static none scroll
# 0028 text-flow static none scroll
# 0029 text-flow static none scroll
# 0030 text-flow static none scroll
# 0031 text-flow static none scroll
# 0032 text-flow static none scroll
# 0033 text-flow static none scroll
# 0034 text-flow static none scroll
# 0035 text-flow static none scroll
# 0036 text-flow static none scroll
# 0037 text-flow static none scroll
# 0038 text-flow static none scroll
#
#
# black-family-heirlooms-juneteenth.xml
# Black Family Heirlooms Juneteenth / New York Times / 2021
#
#
#
# dinner-bill-restaurant-costs-inflation.xml
# Dinner Bill Restaurant Costs Inflation / New York Times / 2022
#
# 0001 static-image static none scroll
# 0002 text-flow static none scroll
# 0003 text-flow static none scroll
# 0004 text-flow static none scroll
# 0005 static-image static none scroll
# 0006 static-image static none scroll
# 0007 static-image static none scroll
# 0008 text-flow static none scroll
# 0009 text-flow static none scroll
# 0010 text-flow static none scroll
# 0011 text-flow static none scroll
# 0012 text-flow static none scroll
# 0013 text-flow static none scroll
# 0014 text-flow static none scroll
# 0015 text-flow static none scroll
# 0016 text-flow static none scroll
# 0017 text-flow static none scroll
# 0018 text-flow static none scroll
# 0019 text-flow static none scroll
# 0020 text-flow static none scroll
# 0021 text-flow static none scroll
# 0022 text-flow static none scroll
# 0023 text-flow static none scroll
# 0024 text-flow static none scroll
# 0025 text-flow static none scroll
# 0026 text-flow static none scroll
# 0027 text-flow static none scroll
# 0028 text-flow static none scroll
# 0029 text-flow static none scroll
# 0030 text-flow static none scroll
# 0031 text-flow static none scroll
# 0032 static-image static none scroll
# 0033 static-image static none scroll
# 0034 static-image static none scroll
# 0035 text-flow static none scroll
# 0036 text-flow static none scroll
# 0037 text-flow static none scroll
#
#
# tennis-serve-ball-toss.xml
# Tennis Serve Ball Toss / New York Times / 2022
#
# 0001 text-flow static none scroll
# 0002 text-flow static none scroll
# 0003 text-flow static none scroll
# 0004 text-flow static none scroll
# 0005 text-flow static none scroll
# 0006 text-flow static none scroll
# 0007 text-flow static none scroll
# 0008 text-flow static none scroll
# 0009 text-flow static none scroll
# 0010 text-flow static none scroll
# 0011 text-flow static none scroll
# 0012 text-flow static none scroll
# 0013 text-flow static none scroll
# 0014 text-flow static none scroll
# 0015 text-flow static none scroll
# 0016 text-flow static none scroll
# 0017 text-flow static none scroll
# 0018 text-flow static none scroll
# 0019 text-flow static none scroll
# 0020 text-flow static none scroll
# 0021 text-flow static none scroll
# 0022 text-flow static none scroll
# 0023 dynamic-image-flow dynamic none scroll
# 0024 text-flow static none scroll
#
#
# russia-putin-war-failures-ukraine.xml
# Russia Putin War Failures Ukraine / New York Times / 2022
#
# 0001 static-image static none scroll
# 0002 dynamic-image-flow dynamic none scroll
# 0003 dynamic-image-flow dynamic none scroll
# 0004 static-image static none scroll
# 0005 dynamic-image-flow dynamic none scroll
# 0006 dynamic-image-flow dynamic none scroll
# 0007 text-flow static none scroll
# 0008 text-flow static none scroll
# 0009 text-flow static none scroll
# 0010 text-flow static none scroll
# 0011 text-flow static none scroll
# 0012 text-flow static none scroll
# 0013 text-flow static none scroll
# 0014 text-flow static none scroll
# 0015 text-flow static none scroll
# 0016 text-flow static none scroll
# 0017 text-flow static none scroll
# 0018 text-flow static none scroll
# 0019 text-flow static none scroll
# 0020 text-flow static none scroll
# 0021 text-flow static none scroll
# 0022 text-flow static none scroll
# 0023 text-flow static none scroll
# 0024 text-flow static none scroll
# 0025 text-flow static none scroll
# 0026 text-flow static none scroll
# 0027 text-flow static none scroll
# 0028 text-flow static none scroll
# 0029 text-flow static none scroll
# 0030 text-flow static none scroll
# 0031 text-flow static none scroll
# 0032 static-image static none scroll
# 0033 text-flow static none scroll
# 0034 text-flow static none scroll
# 0035 static-image static none scroll
# 0036 text-flow static none scroll
# 0037 text-flow static none scroll
# 0038 text-flow static none scroll
# 0039 text-flow static none scroll
# 0040 text-flow static none scroll
# 0041 text-flow static none scroll
# 0042 text-flow static none scroll
# 0043 text-flow static none scroll
# 0044 text-flow static none scroll
# 0045 text-flow static none scroll
# 0046 text-flow static none scroll
# 0047 text-flow static none scroll
# 0048 text-flow static none scroll
# 0049 text-flow static none scroll
# 0050 text-flow static none scroll
# 0051 text-flow static none scroll
# 0052 text-flow static none scroll
# 0053 text-flow static none scroll
# 0054 text-flow static none scroll
# 0055 static-image static none scroll
# 0056 dynamic-image-flow dynamic none scroll
# 0057 dynamic-image-flow dynamic none scroll
# 0058 static-image static none scroll
# 0059 dynamic-image-flow dynamic none scroll
# 0060 dynamic-image-flow dynamic none scroll
# 0061 static-image static none scroll
# 0062 dynamic-image-flow dynamic none scroll
# 0063 dynamic-image-flow dynamic none scroll
# 0064 text-flow static none scroll
# 0065 text-flow static none scroll
# 0066 text-flow static none scroll
# 0067 text-flow static none scroll
# 0068 text-flow static none scroll
# 0069 text-flow static none scroll
# 0070 text-flow static none scroll
# 0071 text-flow static none scroll
# 0072 text-flow static none scroll
# 0073 text-flow static none scroll
# 0074 text-flow static none scroll
# 0075 text-flow static none scroll
# 0076 text-flow static none scroll
# 0077 text-flow static none scroll
# 0078 text-flow static none scroll
# 0079 text-flow static none scroll
# 0080 text-flow static none scroll
# 0081 text-flow static none scroll
# 0082 text-flow static none scroll
# 0083 text-flow static none scroll
# 0084 text-flow static none scroll
# 0085 text-flow static none scroll
# 0086 text-flow static none scroll
# 0087 text-flow static none scroll
# 0088 text-flow static none scroll
# 0089 text-flow static none scroll
# 0090 text-flow static none scroll
# 0091 text-flow static none scroll
# 0092 static-image static none scroll
# 0093 text-flow static none scroll
# 0094 text-flow static none scroll
# 0095 text-flow static none scroll
# 0096 text-flow static none scroll
# 0097 text-flow static none scroll
# 0098 static-image static none scroll
# 0099 text-flow static none scroll
# 0100 text-flow static none scroll
# 0101 text-flow static none scroll
# 0102 text-flow static none scroll
# 0103 text-flow static none scroll
# 0104 dynamic-image-flow dynamic none scroll
# 0105 dynamic-image-flow dynamic none scroll
# 0106 text-flow static none scroll
# 0107 text-flow static none scroll
# 0108 text-flow static none scroll
# 0109 text-flow static none scroll
# 0110 text-flow static none scroll
# 0111 text-flow static none scroll
# 0112 text-flow static none scroll
# 0113 text-flow static none scroll
# 0114 text-flow static none scroll
# 0115 text-flow static none scroll
# 0116 text-flow static none scroll
# 0117 text-flow static none scroll
# 0118 text-flow static none scroll
# 0119 static-image static none scroll
# 0120 text-flow static none scroll
# 0121 text-flow static none scroll
# 0122 text-flow static none scroll
# 0123 text-flow static none scroll
# 0124 text-flow static none scroll
# 0125 text-flow static none scroll
# 0126 text-flow static none scroll
# 0127 text-flow static none scroll
# 0128 dynamic-image-flow dynamic none scroll
# 0129 dynamic-image-flow dynamic none scroll
# 0130 text-flow static none scroll
# 0131 text-flow static none scroll
# 0132 text-flow static none scroll
# 0133 static-image static none scroll
# 0134 text-flow static none scroll
# 0135 text-flow static none scroll
# 0136 text-flow static none scroll
# 0137 text-flow static none scroll
# 0138 text-flow static none scroll
# 0139 text-flow static none scroll
# 0140 text-flow static none scroll
# 0141 text-flow static none scroll
# 0142 text-flow static none scroll
# 0143 text-flow static none scroll
# 0144 text-flow static none scroll
# 0145 text-flow static none scroll
# 0146 text-flow static none scroll
# 0147 text-flow static none scroll
# 0148 static-image static none scroll
# 0149 dynamic-image-flow dynamic none scroll
# 0150 dynamic-image-flow dynamic none scroll
# 0151 static-image static none scroll
# 0152 dynamic-image-flow dynamic none scroll
# 0153 dynamic-image-flow dynamic none scroll
# 0154 static-image static none scroll
# 0155 dynamic-image-flow dynamic none scroll
# 0156 dynamic-image-flow dynamic none scroll
# 0157 text-flow static none scroll
# 0158 text-flow static none scroll
# 0159 text-flow static none scroll
# 0160 text-flow static none scroll
# 0161 text-flow static none scroll
# 0162 text-flow static none scroll
# 0163 text-flow static none scroll
# 0164 text-flow static none scroll
# 0165 text-flow static none scroll
# 0166 text-flow static none scroll
# 0167 text-flow static none scroll
# 0168 text-flow static none scroll
# 0169 text-flow static none scroll
# 0170 text-flow static none scroll
# 0171 text-flow static none scroll
# 0172 text-flow static none scroll
# 0173 text-flow static none scroll
# 0174 text-flow static none scroll
# 0175 text-flow static none scroll
# 0176 text-flow static none scroll
# 0177 text-flow static none scroll
# 0178 text-flow static none scroll
# 0179 text-flow static none scroll
# 0180 text-flow static none scroll
# 0181 text-flow static none scroll
# 0182 text-flow static none scroll
# 0183 text-flow static none scroll
# 0184 text-flow static none scroll
# 0185 text-flow static none scroll
# 0186 text-flow static none scroll
# 0187 text-flow static none scroll
# 0188 text-flow static none scroll
# 0189 text-flow static none scroll
# 0190 text-flow static none scroll
# 0191 text-flow static none scroll
# 0192 text-flow static none scroll
# 0193 text-flow static none scroll
# 0194 text-flow static none scroll
# 0195 text-flow static none scroll
# 0196 text-flow static none scroll
# 0197 text-flow static none scroll
# 0198 text-flow static none scroll
# 0199 text-flow static none scroll
# 0200 text-flow static none scroll
# 0201 text-flow static none scroll
# 0202 text-flow static none scroll
# 0203 text-flow static none scroll
# 0204 text-flow static none scroll
# 0205 text-flow static none scroll
# 0206 text-flow static none scroll
# 0207 text-flow static none scroll
# 0208 text-flow static none scroll
# 0209 text-flow static none scroll
# 0210 text-flow static none scroll
# 0211 text-flow static none scroll
# 0212 text-flow static none scroll
# 0213 text-flow static none scroll
# 0214 text-flow static none scroll
# 0215 text-flow static none scroll
# 0216 text-flow static none scroll
# 0217 text-flow static none scroll
# 0218 text-flow static none scroll
# 0219 text-flow static none scroll
# 0220 text-flow static none scroll
# 0221 text-flow static none scroll
# 0222 text-flow static none scroll
# 0223 text-flow static none scroll
# 0224 text-flow static none scroll
# 0225 text-flow static none scroll
# 0226 text-flow static none scroll
# 0227 text-flow static none scroll
# 0228 text-flow static none scroll
# 0229 dynamic-image-flow dynamic none scroll
# 0230 dynamic-image-flow dynamic none scroll
# 0231 text-flow static none scroll
# 0232 text-flow static none scroll
# 0233 text-flow static none scroll
# 0234 text-flow static none scroll
# 0235 text-flow static none scroll
# 0236 text-flow static none scroll
# 0237 text-flow static none scroll
# 0238 text-flow static none scroll
# 0239 text-flow static none scroll
# 0240 text-flow static none scroll
# 0241 text-flow static none scroll
# 0242 text-flow static none scroll
# 0243 text-flow static none scroll
# 0244 text-flow static none scroll
# 0245 text-flow static none scroll
# 0246 text-flow static none scroll
# 0247 dynamic-image-flow dynamic none scroll
# 0248 dynamic-image-flow dynamic none scroll
# 0249 text-flow static none scroll
# 0250 text-flow static none scroll
# 0251 text-flow static none scroll
# 0252 text-flow static none scroll
# 0253 text-flow static none scroll
# 0254 text-flow static none scroll
# 0255 text-flow static none scroll
# 0256 text-flow static none scroll
# 0257 text-flow static none scroll
# 0258 text-flow static none scroll
# 0259 text-flow static none scroll
# 0260 text-flow static none scroll
# 0261 text-flow static none scroll
# 0262 text-flow static none scroll
# 0263 text-flow static none scroll
# 0264 text-flow static none scroll
# 0265 text-flow static none scroll
# 0266 text-flow static none scroll
# 0267 text-flow static none scroll
# 0268 text-flow static none scroll
# 0269 text-flow static none scroll
# 0270 text-flow static none scroll
# 0271 text-flow static none scroll
# 0272 text-flow static none scroll
# 0273 text-flow static none scroll
# 0274 text-flow static none scroll
# 0275 text-flow static none scroll
# 0276 text-flow static none scroll
# 0277 text-flow static none scroll
# 0278 text-flow static none scroll
# 0279 text-flow static none scroll
# 0280 text-flow static none scroll
# 0281 text-flow static none scroll
# 0282 text-flow static none scroll
# 0283 text-flow static none scroll
# 0284 text-flow static none scroll
# 0285 text-flow static none scroll
# 0286 text-flow static none scroll
# 0287 static-image static none scroll
# 0288 text-flow static none scroll
# 0289 text-flow static none scroll
# 0290 text-flow static none scroll
# 0291 text-flow static none scroll
# 0292 text-flow static none scroll
# 0293 text-flow static none scroll
# 0294 text-flow static none scroll
# 0295 text-flow static none scroll
# 0296 text-flow static none scroll
# 0297 text-flow static none scroll
# 0298 text-flow static none scroll
# 0299 text-flow static none scroll
# 0300 text-flow static none scroll
# 0301 text-flow static none scroll
# 0302 text-flow static none scroll
# 0303 text-flow static none scroll
# 0304 text-flow static none scroll
# 0305 text-flow static none scroll
# 0306 text-flow static none scroll
# 0307 text-flow static none scroll
# 0308 text-flow static none scroll
# 0309 text-flow static none scroll
# 0310 static-image static none scroll
# 0311 text-flow static none scroll
# 0312 text-flow static none scroll
# 0313 text-flow static none scroll
# 0314 text-flow static none scroll
# 0315 text-flow static none scroll
# 0316 text-flow static none scroll
# 0317 text-flow static none scroll
# 0318 text-flow static none scroll
# 0319 text-flow static none scroll
# 0320 text-flow static none scroll
# 0321 text-flow static none scroll
# 0322 text-flow static none scroll
# 0323 text-flow static none scroll
# 0324 text-flow static none scroll
# 0325 text-flow static none scroll
# 0326 text-flow static none scroll
# 0327 text-flow static none scroll
# 0328 text-flow static none scroll
# 0329 text-flow static none scroll
# 0330 text-flow static none scroll
# 0331 static-image static none scroll
# 0332 dynamic-image-flow dynamic none scroll
# 0333 dynamic-image-flow dynamic none scroll
# 0334 static-image static none scroll
# 0335 dynamic-image-flow dynamic none scroll
# 0336 dynamic-image-flow dynamic none scroll
# 0337 static-image static none scroll
# 0338 dynamic-image-flow dynamic none scroll
# 0339 dynamic-image-flow dynamic none scroll
# 0340 static-image static none scroll
# 0341 dynamic-image-flow dynamic none scroll
# 0342 dynamic-image-flow dynamic none scroll
# 0343 static-image static none scroll
# 0344 dynamic-image-flow dynamic none scroll
# 0345 dynamic-image-flow dynamic none scroll
# 0346 text-flow static none scroll
# 0347 text-flow static none scroll
# 0348 text-flow static none scroll
# 0349 text-flow static none scroll
# 0350 text-flow static none scroll
# 0351 text-flow static none scroll
# 0352 text-flow static none scroll
# 0353 text-flow static none scroll
# 0354 text-flow static none scroll
# 0355 text-flow static none scroll
# 0356 text-flow static none scroll
# 0357 text-flow static none scroll
# 0358 text-flow static none scroll
# 0359 text-flow static none scroll
# 0360 text-flow static none scroll
# 0361 text-flow static none scroll
# 0362 text-flow static none scroll
# 0363 text-flow static none scroll
# 0364 text-flow static none scroll
# 0365 text-flow static none scroll
# 0366 text-flow static none scroll
# 0367 text-flow static none scroll
# 0368 text-flow static none scroll
# 0369 text-flow static none scroll
# 0370 text-flow static none scroll
# 0371 text-flow static none scroll
# 0372 text-flow static none scroll
# 0373 text-flow static none scroll
# 0374 text-flow static none scroll
# 0375 text-flow static none scroll
# 0376 text-flow static none scroll
# 0377 text-flow static none scroll
# 0378 text-flow static none scroll
# 0379 text-flow static none scroll
# 0380 text-flow static none scroll
# 0381 text-flow static none scroll
# 0382 dynamic-image-flow dynamic none scroll
# 0383 dynamic-image-flow dynamic none scroll
# 0384 text-flow static none scroll
# 0385 text-flow static none scroll
# 0386 text-flow static none scroll
# 0387 text-flow static none scroll
# 0388 text-flow static none scroll
# 0389 text-flow static none scroll
# 0390 text-flow static none scroll
# 0391 text-flow static none scroll
# 0392 text-flow static none scroll
# 0393 text-flow static none scroll
# 0394 text-flow static none scroll
# 0395 text-flow static none scroll
# 0396 text-flow static none scroll
# 0397 text-flow static none scroll
# 0398 text-flow static none scroll
# 0399 text-flow static none scroll
# 0400 text-flow static none scroll
# 0401 text-flow static none scroll
# 0402 text-flow static none scroll
# 0403 static-image static none scroll
# 0404 dynamic-image-flow dynamic none scroll
# 0405 dynamic-image-flow dynamic none scroll
# 0406 text-flow static none scroll
# 0407 text-flow static none scroll
# 0408 text-flow static none scroll
# 0409 text-flow static none scroll
# 0410 text-flow static none scroll
# 0411 text-flow static none scroll
# 0412 text-flow static none scroll
# 0413 text-flow static none scroll
# 0414 text-flow static none scroll
# 0415 text-flow static none scroll
# 0416 text-flow static none scroll
# 0417 text-flow static none scroll
# 0418 text-flow static none scroll
# 0419 text-flow static none scroll
# 0420 text-flow static none scroll
# 0421 text-flow static none scroll
# 0422 text-flow static none scroll
# 0423 text-flow static none scroll
# 0424 text-flow static none scroll
# 0425 text-flow static none scroll
# 0426 text-flow static none scroll
# 0427 text-flow static none scroll
# 0428 text-flow static none scroll
# 0429 text-flow static none scroll
# 0430 text-flow static none scroll
# 0431 text-flow static none scroll
# 0432 text-flow static none scroll
# 0433 text-flow static none scroll
# 0434 text-flow static none scroll
# 0435 text-flow static none scroll
# 0436 text-flow static none scroll
# 0437 text-flow static none scroll
# 0438 text-flow static none scroll
# 0439 text-flow static none scroll
# 0440 text-flow static none scroll
# 0441 text-flow static none scroll
# 0442 text-flow static none scroll
# 0443 text-flow static none scroll
# 0444 text-flow static none scroll
# 0445 text-flow static none scroll
#
#
# brown-noise.xml
# Brown Noise / New York Times / 2022
#
# 0001 static-image static none scroll
# 0002 static-image static none scroll
# 0003 static-image static none scroll
# 0004 static-image static none scroll
# 0005 static-image static none scroll
# 0006 static-image static none scroll
# 0007 text-flow static none scroll
# 0008 audio static none scroll
# 0009 text-flow static none scroll
# 0010 text-flow static none scroll
# 0011 text-flow static none scroll
# 0012 text-flow static none scroll
# 0013 text-flow static none scroll
# 0014 text-flow static none scroll
# 0015 text-flow static none scroll
# 0016 text-flow static none scroll
# 0017 text-flow static none scroll
# 0018 text-flow static none scroll
# 0019 text-flow static none scroll
# 0020 text-flow static none scroll
# 0021 text-flow static none scroll
# 0022 text-flow static none scroll
# 0023 text-flow static none scroll
# 0024 text-flow static none scroll
# 0025 text-flow static none scroll
# 0026 text-flow static none scroll
# 0027 text-flow static none scroll
# 0028 text-flow static none scroll
# 0029 text-flow static none scroll
# 0030 text-flow static none scroll
# 0031 text-flow static none scroll
# 0032 text-flow static none scroll
# 0033 text-flow static none scroll
# 0034 text-flow static none scroll
# 0035 text-flow static none scroll
# 0036 text-flow static none scroll
#
#
# oval-office-art.xml
# Oval Office Art / New York Times / 2021
#
# 0001 static-image static none scroll
# 0002 static-image static none scroll
# 0003 static-image static none scroll
# 0004 static-image static none scroll
# 0005 text-flow static none scroll
# 0006 static-image static none scroll
# 0007 text-flow static none scroll
# 0008 text-flow static none scroll
# 0009 static-image static none scroll
# 0010 text-flow static none scroll
# 0011 text-flow static none scroll
# 0012 static-image static none scroll
# 0013 text-flow static none scroll
# 0014 text-flow static none scroll
# 0015 static-image static none scroll
# 0016 text-flow static none scroll
# 0017 text-flow static none scroll
# 0018 static-image static none scroll
# 0019 text-flow static none scroll
# 0020 text-flow static none scroll
# 0021 static-image static none scroll
# ...
#
# 0001 text-flow static none scroll
# 0002 text-flow static none scroll
# 0003 text-flow static none scroll
# 0004 text-flow static none scroll
# 0005 text-flow static none scroll
# 0006 text-flow static none scroll
#
#
# trump-voter-fraud-election.xml
# Trump Voter Fraud Election / New York Times / 2020
#
# 0001 text-flow static none scroll
# 0002 dynamic-image-flow dynamic none scroll
# 0003 dynamic-image-flow dynamic none scroll
# 0004 text-flow static none scroll
# 0005 text-flow static none scroll
# 0006 text-flow static none scroll
# 0007 text-flow static none scroll
# 0008 text-flow static none scroll
# 0009 text-flow static none scroll
# 0010 text-flow static none scroll
# 0011 text-flow static none scroll
# 0012 text-flow static none scroll
# 0013 dynamic-image-flow dynamic none scroll
# 0014 dynamic-image-flow dynamic none scroll
# 0015 text-flow static none scroll
# 0016 text-flow static none scroll
#
#
# vaccines-seniors.xml
# Vaccines Seniors / New York Times / 2021
#
# 0001 text-flow static none scroll
# 0002 text-flow static none scroll
# 0003 text-flow static none scroll
# 0004 text-flow static none scroll
# 0005 text-flow static none scroll
# 0006 text-flow static none scroll
# 0007 text-flow static none scroll
# 0008 text-flow static none scroll
# 0009 text-flow static none scroll
# 0010 text-flow static none scroll
# 0011 text-flow static none scroll
# 0012 text-flow static none scroll
# 0013 text-flow static none scroll
# 0014 text-flow static none scroll
# 0015 text-flow static none scroll
# 0016 text-flow static none scroll
# 0017 text-flow static none scroll
# 0018 text-flow static none scroll
# 0019 text-flow static none scroll
#
#
# worker-productivity-tracking.xml
# Worker Productivity Tracking / New York Times / 2022
#
# 0001 text-flow static none scroll
# 0002 text-flow static none scroll
# 0003 text-flow static none scroll
# 0004 text-flow static none scroll
# 0005 text-flow static none scroll
# 0006 text-flow static none scroll
# 0007 text-flow static none scroll
# 0008 text-flow static none scroll
# 0009 static-image static none scroll
# 0010 static-image static none scroll
# 0011 text-flow static none scroll
# 0012 text-flow static none scroll
# 0013 text-flow static none scroll
# 0014 text-flow static none scroll
# 0015 static-image static none scroll
# 0016 static-image static none scroll
# 0017 text-flow static none scroll
# 0018 text-flow static none scroll
# 0019 text-flow static none scroll
# 0020 text-flow static none scroll
# 0021 text-flow static none scroll
# 0022 text-flow static none scroll
# 0023 text-flow static none scroll
# 0024 text-flow static none scroll
# 0025 text-flow static none scroll
# 0026 static-image static none scroll
# 0027 static-image static none scroll
# 0028 text-flow static none scroll
# 0029 text-flow static none scroll
# 0030 text-flow static none scroll
# 0031 text-flow static none scroll
# 0032 text-flow static none scroll
# 0033 text-flow static none scroll
# 0034 static-image static none scroll
# 0035 static-image static none scroll
# 0036 text-flow static none scroll
# 0037 text-flow static none scroll
# 0038 text-flow static none scroll
# 0039 text-flow static none scroll
# 0040 static-image static none scroll
# 0041 static-image static none scroll
# 0042 text-flow static none scroll
# 0043 text-flow static none scroll
# 0044 text-flow static none scroll
# 0045 text-flow static none scroll
# 0046 static-image static none scroll
# 0047 static-image static none scroll
# 0048 text-flow static none scroll
# 0049 text-flow static none scroll
# 0050 text-flow static none scroll
# 0051 static-image static none scroll
# 0052 static-image static none scroll
# 0053 text-flow static none scroll
# 0054 text-flow static none scroll
# 0055 text-flow static none scroll
# 0056 text-flow static none scroll
# 0057 text-flow static none scroll
# 0058 text-flow static none scroll
# 0059 text-flow static none scroll
# 0060 text-flow static none scroll
# 0061 static-image static none scroll
# 0062 static-image static none scroll
# 0063 text-flow static none scroll
# 0064 text-flow static none scroll
# 0065 text-flow static none scroll
# 0066 text-flow static none scroll
# 0067 text-flow static none scroll
# 0068 text-flow static none scroll
# 0069 text-flow static none scroll
# 0070 static-image static none scroll
# 0071 static-image static none scroll
# 0072 text-flow static none scroll
# 0073 text-flow static none scroll
# 0074 text-flow static none scroll
# 0075 text-flow static none scroll
# 0076 static-image static none scroll
# 0077 static-image static none scroll
# 0078 text-flow static none scroll
# 0079 text-flow static none scroll
# 0080 text-flow static none scroll
# 0081 text-flow static none scroll
# 0082 text-flow static none scroll
# 0083 text-flow static none scroll
# 0084 text-flow static none scroll
# 0085 text-flow static none scroll
# 0086 text-flow static none scroll
#
#
# working-moms-coronavirus.xml
# Working Moms Coronavirus / New York Times / 2019
#
# 0001 audio static none scroll
# 0002 static-image static none scroll
# 0003 static-image static none scroll
# 0004 audio static none scroll
# 0005 static-image static none scroll
# 0006 static-image static none scroll
# 0007 static-image static none scroll
# 0008 static-image static none scroll
# 0009 audio static none scroll
# 0010 static-image static none scroll
# 0011 audio static none scroll
# 0012 static-image static none scroll
# 0013 static-image static none scroll
# 0014 audio static none scroll
# 0015 static-image static none scroll
# 0016 static-image static none scroll
# 0017 static-image static none scroll
# 0018 audio static none scroll
# 0019 static-image static none scroll
# 0020 audio static none scroll
# 0021 text-flow static none scroll
# 0022 text-flow static none scroll
# 0023 text-flow static none scroll
# 0024 text-flow static none scroll
# 0025 text-flow static none scroll
# 0026 text-flow static none scroll
# 0027 text-flow static none scroll
# 0028 text-flow static none scroll
# 0029 text-flow static none scroll
# 0030 text-flow static none scroll
# 0031 text-flow static none scroll
# 0032 text-flow static none scroll
# 0033 text-flow static none scroll
# 0034 text-flow static none scroll
# 0035 text-flow static none scroll
# 0036 text-flow static none scroll
# 0037 text-flow static none scroll
# 0038 text-flow static none scroll
# 0039 text-flow static none scroll
# 0040 text-flow static none scroll
#
#
# bubble-politics.xml
# Bubble Politics / New York Times / 2020
#
# 0001 text-flow static none scroll
# 0002 text-flow static none scroll
# 0003 text-flow static none scroll
# 0004 text-flow static none scroll
# 0005 text-flow static none scroll
# 0006 text-flow static none scroll
# 0007 text-flow static none scroll
# 0008 text-flow static none scroll
# 0009 text-flow static none scroll
# 0010 text-flow static none scroll
# 0011 text-flow static none scroll
# 0012 text-flow static none scroll
# 0013 text-flow static none scroll
# 0014 text-flow static none scroll
# 0015 text-flow static none scroll
# 0016 text-flow static none scroll
# 0017 text-flow static none scroll
# 0018 text-flow static none scroll
# 0019 text-flow static none scroll
# 0020 text-flow static none scroll
# 0021 text-flow static none scroll
# 0022 text-flow static none scroll
# 0023 text-flow static none scroll
# 0024 text-flow static none scroll
# 0025 text-flow static none scroll
# 0026 text-flow static none scroll
# 0027 text-flow static none scroll
# 0028 text-flow static none scroll
# 0029 text-flow static none scroll
#
#
# china-fishing-south-america.xml
# China Fishing South America / New York Times / 2022
#
# 0001 text-flow static none scroll
# 0002 text-flow static none scroll
# 0003 static-image static none scroll
# 0004 text-flow static none scroll
# 0005 text-flow static none scroll
# 0006 text-flow static none scroll
# 0007 text-flow static none scroll
# 0008 text-flow static none scroll
# 0009 text-flow static none scroll
# 0010 text-flow static none scroll
# 0011 text-flow static none scroll
# 0012 text-flow static none scroll
# 0013 static-image static none scroll
# 0014 text-flow static none scroll
# 0015 text-flow static none scroll
# 0016 text-flow static none scroll
# 0017 text-flow static none scroll
# 0018 text-flow static none scroll
# 0019 text-flow static none scroll
# 0020 text-flow static none scroll
# 0021 text-flow static none scroll
# 0022 text-flow static none scroll
# 0023 text-flow static none scroll
# 0024 text-flow static none scroll
# 0025 text-flow static none scroll
# 0026 text-flow static none scroll
# 0027 text-flow static none scroll
# 0028 text-flow static none scroll
# 0029 text-flow static none scroll
# 0030 text-flow static none scroll
# 0031 text-flow static none scroll
# 0032 static-image static none scroll
# 0033 text-flow static none scroll
# 0034 text-flow static none scroll
# 0035 text-flow static none scroll
# 0036 text-flow static none scroll
# 0037 text-flow static none scroll
# 0038 text-flow static none scroll
# 0039 text-flow static none scroll
#
#
# redistricting-maps-explained.xml
# Redistricting Maps Explained / New York Times / 2021
#
# 0001 text-flow static none scroll
# 0002 text-flow static none scroll
# 0003 text-flow static none scroll
# 0004 text-flow static none scroll
# 0005 text-flow static none scroll
# 0006 text-flow static none scroll
# 0007 text-flow static none scroll
# 0008 text-flow static none scroll
# 0009 text-flow static none scroll
# 0010 text-flow static none scroll
# 0011 text-flow static none scroll
# 0012 text-flow static none scroll
# 0013 text-flow static none scroll
# 0014 text-flow static none scroll
# 0015 text-flow static none scroll
# 0016 text-flow static none scroll
# 0017 text-flow static none scroll
# 0018 text-flow static none scroll
# 0019 text-flow static none scroll
# 0020 text-flow static none scroll
# 0021 text-flow static none scroll
# 0022 text-flow static none scroll
# 0023 text-flow static none scroll
# 0024 text-flow static none scroll
# 0025 text-flow static none scroll
# 0026 text-flow static none scroll
# 0027 text-flow static none scroll
# 0028 text-flow static none scroll
# 0029 text-flow static none scroll
# 0030 text-flow static none scroll
# 0031 text-flow static none scroll
# 0032 text-flow static none scroll
# 0033 text-flow static none scroll
# 0034 text-flow static none scroll
# 0035 text-flow static none scroll
# 0036 text-flow static none scroll
# 0037 text-flow static none scroll
# 0038 text-flow static none scroll
# 0039 text-flow static none scroll
# 0040 text-flow static none scroll
# 0041 text-flow static none scroll
# 0042 text-flow static none scroll
# 0043 text-flow static none scroll
# 0044 text-flow static none scroll
# 0045 text-flow static none scroll
# 0046 text-flow static none scroll
# 0047 text-flow static none scroll
# 0048 text-flow static none scroll
# 0049 text-flow static none scroll
# 0050 text-flow static none scroll
# 0051 text-flow static none scroll
# 0052 text-flow static none scroll
# 0053 text-flow static none scroll
# 0054 text-flow static none scroll
# 0055 text-flow static none scroll
# 0056 text-flow static none scroll
# 0057 text-flow static none scroll
# 0058 text-flow static none scroll
# 0059 text-flow static none scroll
# 0060 text-flow static none scroll
# 0061 text-flow static none scroll
# 0062 text-flow static none scroll
# 0063 text-flow static none scroll
# 0064 text-flow static none scroll
# 0065 text-flow static none scroll
#
#
# coronavirus-pandemic.xml
# Coronavirus Pandemic / New York Times / 2019
#
# 0001 static-image static none scroll
# 0002 static-image static none scroll
# 0003 static-image static none scroll
# 0004 static-image static none scroll
# 0005 static-image static none scroll
# 0006 static-image static none scroll
# 0007 static-image static none scroll
# 0008 static-image static none scroll
# 0009 static-image static none scroll
# 0010 static-image static none scroll
# 0011 static-image static none scroll
# 0012 static-image static none scroll
# 0013 static-image static none scroll
# 0014 static-image static none scroll
# 0015 static-image static none scroll
# 0016 static-image static none scroll
# 0017 static-image static none scroll
# 0018 static-image static none scroll
# 0019 static-image static none scroll
# 0020 static-image static none scroll
# 0021 static-image static none scroll
# 0022 static-image static none scroll
# 0023 static-image static none scroll
# 0024 static-image static none scroll
# 0025 static-image static none scroll
# 0026 static-image static none scroll
# 0027 static-image static none scroll
# 0028 static-image static none scroll
# 0029 static-image static none scroll
# 0030 static-image static none scroll
# 0031 static-image static none scroll
# 0032 static-image static none scroll
# 0033 static-image static none scroll
# 0034 static-image static none scroll
# 0035 static-image static none scroll
# 0036 static-image static none scroll
# 0037 static-image static none scroll
# 0038 static-image static none scroll
# 0039 static-image static none scroll
# 0040 static-image static none scroll
# 0041 static-image static none scroll
# 0042 static-image static none scroll
# 0043 static-image static none scroll
# 0044 static-image static none scroll
# 0045 static-image static none scroll
# 0046 static-image static none scroll
# 0047 static-image static none scroll
# 0048 static-image static none scroll
# 0049 static-image static none scroll
# 0050 static-image static none scroll
# 0051 static-image static none scroll
# 0052 static-image static none scroll
# 0053 static-image static none scroll
# 0054 dynamic-image-flow dynamic none scroll
# 0055 dynamic-image-flow dynamic none scroll
# 0056 static-image static none scroll
# 0057 static-image static none scroll
# 0058 static-image static none scroll
# 0059 static-image static none scroll
# 0060 static-image static none scroll
# 0061 static-image static none scroll
# 0062 static-image static none scroll
# 0063 static-image static none scroll
# 0064 static-image static none scroll
# 0065 static-image static none scroll
# 0066 static-image static none scroll
# 0067 static-image static none scroll
# 0068 static-image static none scroll
# 0069 static-image static none scroll
# 0070 static-image static none scroll
# 0071 static-image static none scroll
# 0072 static-image static none scroll
# 0073 static-image static none scroll
# 0074 static-image static none scroll
# 0075 static-image static none scroll
# 0076 static-image static none scroll
# 0077 static-image static none scroll
# 0078 static-image static none scroll
# 0079 static-image static none scroll
# 0080 static-image static none scroll
# 0081 static-image static none scroll
# 0082 static-image static none scroll
# 0083 static-image static none scroll
# 0084 static-image static none scroll
# 0085 static-image static none scroll
# 0086 static-image static none scroll
# 0087 static-image static none scroll
# 0088 static-image static none scroll
# 0089 static-image static none scroll
# 0090 static-image static none scroll
# 0091 static-image static none scroll
# 0092 static-image static none scroll
# 0093 static-image static none scroll
# 0094 static-image static none scroll
# 0095 static-image static none scroll
# 0096 static-image static none scroll
# 0097 static-image static none scroll
# 0098 static-image static none scroll
# 0099 static-image static none scroll
# 0100 static-image static none scroll
# 0101 static-image static none scroll
# 0102 static-image static none scroll
# 0103 static-image static none scroll
# 0104 static-image static none scroll
# 0105 static-image static none scroll
# 0106 static-image static none scroll
# 0107 static-image static none scroll
# 0108 static-image static none scroll
# 0109 static-image static none scroll
# 0110 static-image static none scroll
# 0111 static-image static none scroll
# 0112 static-image static none scroll
# 0113 static-image static none scroll
# 0114 static-image static none scroll
# 0115 static-image static none scroll
# 0116 static-image static none scroll
# 0117 static-image static none scroll
# 0118 static-image static none scroll
# 0119 static-image static none scroll
# 0120 static-image static none scroll
# 0121 static-image static none scroll
# 0122 static-image static none scroll
# 0123 static-image static none scroll
# 0124 static-image static none scroll
# 0125 static-image static none scroll
# 0126 static-image static none scroll
# 0127 static-image static none scroll
# 0128 static-image static none scroll
# 0129 static-image static none scroll
# 0130 static-image static none scroll
# 0131 static-image static none scroll
#
#
# climate-change-risks-by-country.xml
# Climate Change Risks By Country / New York Times / 2021
#
# 0001 text-flow static none scroll

# %%
out = open('articles_modalities.csv' , 'w' , encoding = 'utf-8')

articles = os.listdir(annotations_dir)
articles = [article for article in articles if re.search( r'\.xml$' , article )]
print( f'The dataset contains {len(articles)} articles.' )

modalities = ['text-flow','dynamic-image-flow','audio','dynamic-text','static-image']

## CSV header
out.write('article')
for m in modalities:
    out.write(f',{m}')
out.write('\n')


for article in articles:
    print(article)
    out.write(article)
    screens = []
    path = os.path.join(annotations_dir,article)
    annotation = et.parse(path) 
    xmlroot = annotation.getroot() 
    for screen in xmlroot:
        screens.append( screen.attrib['mode'] )
    screens_count = c(screens)
    for m in modalities:
        out.write( f',{screens_count.get(m,0)}')
    out.write('\n')
    
out.close()
# Out:
# The dataset contains 223 articles.
# miami-building-collapse.xml
# ukraine-maps.xml
# covid-risk-map.xml
# covid-vaccinations-tracker.xml
# infrastructure-breakdown.xml
# san-francisco-fog.xml
# asian-american-photos-love.xml
# olympic-races.xml
# bike-ride-italy-croatia.xml
# environmental-inequity-trees-critical-infrastructure.xml
# major-league-baseball-spin-rate-shift.xml
# ranked-choice-voting-nyc.xml
# covid-prison-outbreak.xml
# dominican-soundsystems.xml
# partisan-segregation-maps.xml
# dinner-bill-restaurant-costs-inflation.xml
# tennis-serve-ball-toss.xml
# russia-putin-war-failures-ukraine.xml
# brown-noise.xml
# oval-office-art.xml
# olympic-running.xml
# bitcoin-carbon-footprint-electricity.xml
# supreme-court-dobbs-jackson-analysis-roe-wade.xml
# xi-propaganda.xml
# congress-stock-trading-investigation.xml
# crimea-bridge-collapse.xml
# guantanamo-bay-pentagon-photos.xml
# record-temperatures-map-2021.xml
# trump-capitol-riot-timeline.xml
# off-white-papers.xml
# powwow-season.xml
# vaccine-mandate-states.xml
# capitol-arrests.xml
# urban-highways-segregation.xml
# ukraine-civilian-attacks.xml
# anti-asian-attacks.xml
# whats-in-democrats-reconciliation-bill.xml
# human-composting-new-york.xml
# roe-v-wade-abortion-history.xml
# helms-amendment-abortion-repeal.xml
# us-cities-highway-removal.xml
# reddit-unemployed.xml
# mexico-city-train-crash.xml
# alt-text-images-descriptions.xml
# nyc-neighborhood-congressional-districts.xml
# shanghai-lockdown.xml
# maternal-pregnancy-health.xml
# biodiversity-map.xml
# cdc-mask-guidance-states.xml
# suni-lee-gymnastics.xml
# year-in-interactive-graphics.xml
# texas-abortion-human-coalition.xml
# russia-private-jets.xml
# product-placement.xml
# republicans-house-congress.xml
# ny-service-workers-covid.xml
# athletes-winter-injuries.xml
# hurricane-ian-fort-myers-beach-damage.xml
# blm-george-floyd-mural.xml
# nyc-mayor-candidates-video.xml
# fbi-mar-a-lago-documents.xml
# pfizer-coronavirus-vaccine.xml
# congress-house-seats-census.xml
# snow-forecast-totals-lookup.xml
# long-covid-causes.xml
# sight-and-sound-best-movies-of-all-time.xml
# twitter-bots-china-protests-elon-musk.xml
# texas-redistricting-map-2022.xml
# dixie-fire-storm-clouds-weather.xml
# egypt-sexual-assault-police.xml
# wildlife-crossings-animals.xml
# mykolaiv-ukraine-firefighters-russia.xml
# tesla-self-driving-flaws.xml
# north-korea-promises.xml
# american-sign-language-changes.xml
# south-asia-monsoon-climate-change.xml
# election-misinformation-midterms-results.xml
# england-covid-hospitals.xml
# brooklyn-streets-numbers-renaming.xml
# extreme-heat.xml
# nyc-chinatown-signs.xml
# miami-building-missing-dead.xml
# biodiversity-habitat-loss-climate.xml
# portland-seattle-vancouver-weather.xml
# covid-hospital-icu-south.xml
# eileen-gu-halfpipe-ski.xml
# tom-brady-of-other-jobs.xml
# tom-brady-career-stats.xml
# brazil-airstrips-illegal-mining.xml
# police-traffic-stops-danger-video.xml
# ukraine-munitions-war-crimes.xml
# peat-carbon-climate-change.xml
# enslaved-haiti-debt-timeline.xml
# india-coronavirus-family.xml
# global-vaccine-supply-inequity.xml
# flying-plane-covid-19-safety.xml
# meryl-streep-acting.xml
# caldor-fire-lake-tahoe.xml
# trump-social-media-ban.xml
# election-results-time.xml
# italy-photos.xml
# china-propaganda-youtube-influencers.xml
# asian-americans.xml
# china-taiwan-conflict-blockade.xml
# sneaker-bots.xml
# plastics-recycling-trash-environment.xml
# kabul-airport-afghanistan-maps.xml
# harlem-gospel-church-choir.xml
# civilian-casualty-files.xml
# ancient-trees-climate-change.xml
# trump-qanon-washington-capitol-hill.xml
# xinjiang-uyghurs-china-propaganda.xml
# biden-budget-before-after-animation.xml
# snowboard-ski-tricks.xml
# hu-jintao-congress-videos.xml
# panic-attack-symptoms-causes.xml
# russian-trench-fortifications-in-ukraine.xml
# covid-deaths-us-one-million.xml
# amazon-workers.xml
# oath-keepers-capitol-riot.xml
# russian-soldiers-phone-calls-ukraine.xml
# covid-deaths.xml
# antarctic-climate-change.xml
# capitol-mob-timeline.xml
# tonga-pressure-wave.xml
# russia-putin-surveillance-spying.xml
# teaching-critical-race-theory.xml
# tulsa-race-massacre.xml
# roger-stone-capitol-riot.xml
# black-surfers.xml
# abortion-laws-roe-v-wade.xml
# hottest-year-2020-global-map.xml
# trump-biden-geography-quiz.xml
# science-fraud-image-manipulation-photoshop.xml
# georgia-senate-results-analysis.xml
# dobbs-roe-abortion-driving-distances.xml
# gender-bias.xml
# covid-death-toll-world.xml
# climate-footprint-map-neighborhood.xml
# europe-covid-surge-omicron.xml
# quad-jumps-figure-skating.xml
# sushi-us.xml
# tucker-carlson-tonight.xml
# abortion-costs-funds.xml
# bronx-fire-nyc.xml
# taiwan-china-maps.xml
# asians-census-us.xml
# world-cup-standings.xml
# octavia-butler-vision-kindred.xml
# covid-19-death-toll.xml
# vaccine-racial-disparities.xml
# omicron-cities-cases-hospitals.xml
# covid-delhi-neighborhood.xml
# fashion-week-highlights-paris-ny-milan.xml
# nyc-mayor-donors-map.xml
# heat-wave-map-tracker.xml
# where-the-despairing-log-on.xml
# office-vaccine-mandate.xml
# tallest-mountain-summit.xml
# year-in-interactive-storytelling.xml
# europe-coronavirus-variants.xml
# covid-inequality-vaccines.xml
# shootings-police-response-uvalde-buffalo.xml
# covid-19-vaccine-hesitancy.xml
# capitol-riot-attack-militants.xml
# nasa-moon-artemis-launch.xml
# maricopa-county-arizona-voting-machines-kari-lake.xml
# best-book-vote.xml
# eu-logging-wood-pellets.xml
# ayumu-hirano-shaun-white-snowboarding-halfpipe.xml
# winter-olympics-photos-pictures.xml
# mass-shooting-gun-laws.xml
# pop-music-songwriting.xml
# best-songs.xml
# covid-vaccination-barriers.xml
# inflation-calculator.xml
# tiangong-space-station.xml
# school-shooting-timeline-uvalde-texas.xml
# kamala-harris-name-sign-language.xml
# climate-change-effects-countries.xml
# 2020-census-race-ethnicity.xml
# auden-musee-des-beaux-arts.xml
# inflation-economy-transitory.xml
# skiing-millie-knight-paralympics-fear.xml
# supreme-court-photo.xml
# ida-oil-spills.xml
# california-rain-storm.xml
# hospital-prices.xml
# biles-vault-gymnastics.xml
# covid-surges.xml
# mar-a-lago-trump-documents.xml
# vaccine-waning-immunity.xml
# subway-train-sounds.xml
# supply-chain.xml
# coronavirus-aerosol-simulation.xml
# ukraine-russia-babyn-yar.xml
# reopen-schools-safety-ventilation.xml
# atlantic-ocean-climate-change.xml
# immigrants-success-america.xml
# results-house-seats-elections-congress.xml
# republican-candidates-2020-election-misinformation.xml
# mexico-missing-people.xml
# kabul-evacuation-afghanistan.xml
# how-a-book-is-made.xml
# f1-new-car-design-miami.xml
# vaccine-hesitancy-politics.xml
# coronavirus-variant-tracker.xml
# rich-poor-friendships.xml
# nathan-chen-jumps.xml
# covid-vaccine-lines-states.xml
# adam-ondra-climbing.xml
# united-states-faith-rituals.xml
# breastfeeding-nursing-formula.xml
# trump-second-impeachment-timeline.xml
# trump-voter-fraud-election.xml
# vaccines-seniors.xml
# worker-productivity-tracking.xml
# working-moms-coronavirus.xml
# bubble-politics.xml
# china-fishing-south-america.xml
# redistricting-maps-explained.xml
# coronavirus-pandemic.xml
# climate-change-risks-by-country.xml

# %%
import pandas as pd

df = pd.read_csv('articles_modalities.csv')

# %%
#df['total'] = df[ modalities ].sum(numeric_only=True, axis=1)
# textual = ['dynamic-text','text-flow']
# non_textual = [m for m in modalities if m not in textual]
# df['textual'] = df[ textual ].sum()
# df['non-textual'] = df[ non_textual].sum()

# %%
df['total'] = df[ modalities].sum(axis=1)

textual = ['dynamic-text','text-flow']
non_textual = [m for m in modalities if m not in textual]

df['textual'] = df[ textual ].sum(axis=1) / df['total']
df['non-textual'] = df[ non_textual].sum(axis=1) / df['total']
# Out:
#                                    article  text-flow  dynamic-image-flow  \
# 0              miami-building-collapse.xml        0.0                 4.0
# 1                         ukraine-maps.xml        9.0                 0.0
# 2                       covid-risk-map.xml        9.0                 0.0
# 3           covid-vaccinations-tracker.xml        8.0                 0.0
# 4             infrastructure-breakdown.xml       16.0                 0.0
# ...                                    ...        ...                 ...
# 219        china-fishing-south-america.xml       36.0                 0.0
# 220       redistricting-maps-explained.xml       65.0                 0.0
# 221               coronavirus-pandemic.xml        0.0                 2.0
# 222    climate-change-risks-by-country.xml        1.0                 0.0
# total                                  NaN        NaN                 NaN
#
#        audio  dynamic-text  static-image  total   textual  non-textual
# 0        0.0           0.0           0.0    4.0  0.000000     1.000000
# 1        0.0           0.0           0.0    9.0  1.000000     0.000000
# 2        0.0           0.0           0.0    9.0  1.000000     0.000000
# 3        0.0           0.0           0.0    8.0  1.000000     0.000000
# 4        0.0           0.0           0.0   16.0  1.000000     0.000000
# ...      ...           ...           ...    ...       ...          ...
# 219      0.0           0.0           3.0   39.0  0.923077     0.076923
# 220      0.0           0.0           0.0   65.0  1.000000     0.000000
# 221      0.0           0.0         129.0  131.0  0.000000     1.000000
# 222      0.0           0.0           0.0    1.0  1.000000     0.000000
# total    NaN           NaN           NaN    0.0       NaN          NaN
#
# [224 rows x 9 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns


fig = plt.figure( figsize = ( 10,10 ))

## This line adds spacing in between the lines of the legend 
sns.set(rc = {'legend.labelspacing': 1.6})


ax = sns.scatterplot( data=df, x= 'textual' , y= 'non-textual'   
                    )

# for index, row in df.iterrows():
#     plt.text( row[x_axis], row[y_axis] , row['country'] , fontsize=12.8)


ax.set_xlabel( 'Textual modalities'  , fontsize = 16 )
ax.set_ylabel( 'Non-textual modalities'  , fontsize = 16 )
ax.set_title( 'Longform articles' , fontsize=24 )


# this next line places the legend outside of the graph
#plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.);

plt.savefig( 'scatterplot.png' , dpi=300 )

# %%
sns.set(style="darkgrid")

df_sorted = df.sort_values(by=[ 'textual'] , ascending = False)

plt.figure(figsize=(30, 8))

ax = sns.barplot(x= df_sorted.index, y="textual", data=df_sorted, dodge=False ,  color='darkblue')
ax.tick_params(labelsize=1)
plt.show()

# %% [markdown]
# This graph display the percentage of textual components. About half of the articles contsist of text only.
# About a tenth of the artcile has non-textual contents only.

# %% [markdown]
# ### Examining the modes preceding a specific semiotic mode

# %%
preceding_mode = []

for current in screens[1:]:
        previous = screens[screens.index(current) -1]
        if current[1] == 'photograph':
            preceding_mode.append(previous[2] + '-' + previous[1])
            
pm = c(preceding_mode)

print( c.most_common(pm) )
# Out:
# []

# %% [markdown]
# ### Examining the modes following a specific semiotic mode

# %%
following_modes = []

for current in screens:
    if screens.index(current) != len(screens) -1:
        following = screens[screens.index(current) +1]
        if current[1] == 'text-flow':
            following_modes.append(following[2] + '-' + following[1])
            
fm = c(following_modes)

print c.most_common(fm)

# %% [markdown]
# ### Examine sequences of semiotic modes

# %%
sequence = []

for current in screens:
    if screens.index(current) != len(screens) -1:
        following = screens[screens.index(current) +1]
        if current[1] != 'text-flow':
            if following[1] != 'text-flow':
                sequence.append(following[0] + ' ' + following[1] + ' followed by ' + current[0] + ' ' + current[1])

# %%
sequence

# %% [markdown]
# ### Counting modes, transitions and mode-transition patterns

# %%
transition_patterns = []

for xmlfile in xmlfiles: # Loop through each XML file
    annotation = et.parse(xmlfile) # Parse the XML annotation in specific file
    xmlroot = annotation.getroot() # Get the root element
    print xmlroot.attrib['title'], '/', xmlroot.attrib['publisher'], '/', xmlroot.attrib['year'], '\n' # Print longform data
    
    content = []
    unique_modes = []
    unique_transitions = []

    for entry in xmlroot: # Iterate through the XML file
        portion = xmlroot.attrib['article_identifier'] + '-' + entry.attrib['identifier'], entry.attrib['mode'], entry.attrib['type'], entry.attrib['transition_in'], entry.attrib['transition_out']
        content.append(portion)
        
        mode = entry.attrib['type'] + ' ' + entry.attrib['mode']
        unique_modes.append(mode)

        transition = entry.attrib['transition_in'] + '-' + entry.attrib['transition_out']
        if 'none' in transition:
            continue
        else:
            unique_transitions.append(transition)        
    
    article_transitions = []
    
    for current in content: # Print the transitions
        if content.index(current) != len(content) -1:
            following = content[content.index(current) +1]
            print 'Transition from ' + current[2] + ' ' + current[1] + ' to ' + following[2] + ' ' + following[1] + ' via ' + current[4] + '/' + following[3] 
            unique_transition = current[2] + ' ' + current[1] + ' to ' + following[2] + ' ' + following[1] + ' via ' + current[4] + '/' + following[3]
            mode = current[2] + ' ' + current[1]
            
            transition_patterns.append(unique_transition)
            article_transitions.append(unique_transition)
        else:
            continue
            
    print '\n' # Extra line break
        
    print 'A total of %i unique modes, %i unique transitions and %i unique mode-transition combinations.' % (len(c(unique_modes)), len(c(unique_transitions)), len(c.most_common(c(article_transitions))))
    
    print '\n' # Extra line break

# %% [markdown]
# ### Counting the semiotic modes

# %%
modes = [] # Empty list for modes

for screen in screens:
    mode = screen[1] + '-' + screen[2]
    modes.append(mode)
    
ms = c(modes)

c.most_common(ms)

# %% [markdown]
# ### Counting the transitions

# %%
transitions = []

for screen in screens:
    transition = screen[3] + '-' + screen[4]
    if 'none' in transition:
        continue
    else:
        transitions.append(transition)

tr = c(transitions)

c.most_common(tr)

# %% [markdown]
# ### Counting symmetric transitions

# %%
sym_transitions = []

for screen in screens:
    transition = screen[3] + '-' + screen[4]
    if screen[3] == screen[4]:
        sym_transitions.append(transition)

symtr = c(sym_transitions)

len(sym_transitions), len(symtr), c.most_common(symtr)

# %% [markdown]
# ### Counting asymmetric transitions

# %%
asym_transitions = []

for screen in screens:
    transition = screen[3] + '-' + screen[4]
    if screen[3] != screen[4]:
        asym_transitions.append(transition)

asymtr = c(asym_transitions)

len(asym_transitions), len(asymtr), c.most_common(asymtr)

# %% [markdown]
# ### Finding the most common transitions for a specific semiotic mode

# %%
single_mode_transitions = []

for m, t in zip(modes, transitions):
    mode_transition = m, t
    if 'text-flow' in m:
        single_mode_transitions.append(mode_transition)

mt = c(single_mode_transitions) # Set up a counter for c.most_common

c.most_common(mt)

# %% [markdown]
# Find the most common transition patterns.

# %%
tp = c(transition_patterns)

c.most_common(tp)
